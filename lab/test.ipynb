# %%
import numpy as np
from skimage.filters import gaussian
from skimage.feature import peak_local_max

# %%
def detect_cells_in_frame(frame_3d_array, min_intensity_treshold):
    """ 
    frame_3d_array: A single 3D numpy array (Z, Y, X) from zarr file.
    min_intensity_treshold: The minimum brightness [0.0 - 1.0] to be considered in cell.
    """
